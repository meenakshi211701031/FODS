# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('diamonds.csv')

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 49995   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [50000 rows x 10 columns]

# %%
df1=df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df1=df.describe()
#
# NameError: name 'df' is not defined

# %%
df.shape
# Out:
# (50000, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    50000 non-null  float64
#  1   cut      50000 non-null  object
#  2   color    50000 non-null  object
#  3   clarity  50000 non-null  object
#  4   depth    50000 non-null  float64
#  5   table    50000 non-null  float64
#  6   price    50000 non-null  int64
#  7   x        50000 non-null  float64
#  8   y        50000 non-null  float64
#  9   z        50000 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 3.8+ MB

# %%
df1 = df.drop_duplicates()

# %%
df1
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 49995   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [49874 rows x 10 columns]

# %%
df2 = df1.dropna()

# %%
df2
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 49995   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [49874 rows x 10 columns]

# %%
print(df['carat'].fillna(df['carat'].mean(), inplace=True))
# Out:
# None

# %%
print(df.cut.value_counts(),'\n',df.color.value_counts(),'\n',df.clarity.value_counts())
# Out:
# Ideal        19938
# Premium      12806
# Very Good    11204
# Good          4557
# Fair          1495
# Name: cut, dtype: int64
#  G    10452
# E     9085
# F     8864
# H     7711
# D     6224
# I     5058
# J     2606
# Name: color, dtype: int64
#  SI1     12115
# VS2     11404
# SI2      8519
# VS1      7579
# VVS2     4694
# VVS1     3369
# IF       1632
# I1        688
# Name: clarity, dtype: int64

# %%
df.head(10)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %%
scaler = StandardScaler()
numerical_features = ['carat', 'depth', 'table', 'x', 'y', 'z']
df[numerical_features] = scaler.fit_transform(df[numerical_features])

# %%
df[numerical_features]
# Out:
#           carat     depth     table         x         y         z
# 0     -1.198405 -0.176795 -1.101144 -1.588868 -1.534572 -1.571380
# 1     -1.240495 -1.364714  1.586944 -1.642293 -1.656782 -1.741097
# 2     -1.198405 -3.391165  3.379003 -1.499826 -1.456009 -1.741097
# 3     -1.072134  0.452104  0.242900 -1.366263 -1.316340 -1.288517
# 4     -1.030043  1.081003  0.242900 -1.241604 -1.211588 -1.118800
# ...         ...       ...       ...       ...       ...       ...
# 49995 -0.167191 -0.665938 -0.205115  0.013888  0.019243 -0.058066
# 49996 -0.167191  0.941247 -1.101144 -0.039538  0.010513  0.097508
# 49997 -0.209281  0.731615  1.138930 -0.066250 -0.050592  0.026793
# 49998  0.127442 -0.526183  0.242900  0.370055  0.333497  0.281369
# 49999 -0.104055  0.312349 -1.101144  0.085121  0.115265  0.139938
#
# [50000 rows x 6 columns]

# %%
df
# Out:
#           carat        cut color clarity     depth     table  price         x  \
# 0     -1.198405      Ideal     E     SI2 -0.176795 -1.101144    326 -1.588868
# 1     -1.240495    Premium     E     SI1 -1.364714  1.586944    326 -1.642293
# 2     -1.198405       Good     E     VS1 -3.391165  3.379003    327 -1.499826
# 3     -1.072134    Premium     I     VS2  0.452104  0.242900    334 -1.366263
# 4     -1.030043       Good     J     SI2  1.081003  0.242900    335 -1.241604
# ...         ...        ...   ...     ...       ...       ...    ...       ...
# 49995 -0.167191      Ideal     D     SI1 -0.665938 -0.205115   2757  0.013888
# 49996 -0.167191       Good     D     SI1  0.941247 -1.101144   2757 -0.039538
# 49997 -0.209281  Very Good     D     SI1  0.731615  1.138930   2757 -0.066250
# 49998  0.127442    Premium     H     SI2 -0.526183  0.242900   2757  0.370055
# 49999 -0.104055      Ideal     D     SI2  0.312349 -1.101144   2757  0.085121
#
#               y         z
# 0     -1.534572 -1.571380
# 1     -1.656782 -1.741097
# 2     -1.456009 -1.741097
# 3     -1.316340 -1.288517
# 4     -1.211588 -1.118800
# ...         ...       ...
# 49995  0.019243 -0.058066
# 49996  0.010513  0.097508
# 49997 -0.050592  0.026793
# 49998  0.333497  0.281369
# 49999  0.115265  0.139938
#
# [50000 rows x 10 columns]

# %%
df = pd.read_csv('diamonds.csv')

# %%
q1=df['price'].quantile(0.25)

# %%
q1
# Out:
# 951.0

# %%
q3=df['price'].quantile(0.75)

# %%
q3
# Out:
# 5351.0

# %%
IQR=q3-q1

# %%
lb=q1-1.5*IQR

# %%
ub=q3+1.5*IQR

# %%
outlier=((df[['price']]<lb) | (df[['price']]>ub)).any(axis=1)

# %%
cleaned=df[~outlier]

# %%
cleaned
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 49995   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [46736 rows x 10 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
Scaler=MinMaxScaler()

# %%
df['depth']=Scaler.fit_transform(df[['depth']])

# %%
#Exploratory Data Analysis

# %%
sns.histplot(df['price'],bins = 20)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.histplot(df['carat'],bins=20)
# Out:
# <Axes: xlabel='carat', ylabel='Count'>

# %%
plt.figure(figsize=(5,5))
plt.pie(df['cut'].value_counts(),labels=['Ideal','Premium','Very Good','Good','Fair'],autopct='%1.1f%%')
plt.title('Cut')
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.bar(df['clarity'].value_counts().index,df['clarity'].value_counts())
plt.title('Clarity')
plt.ylabel("Number of Diamonds")
plt.xlabel("Clarity")
plt.show()

# %%
sns.histplot(df['table'],bins=10)
plt.title('Table')
plt.show()

# %%
#Comparing Diamond's features with Price

# %%
sns.barplot(x='cut',y='price',data=df)
# Out:
# <Axes: xlabel='cut', ylabel='price'>

# %%
sns.barplot(x='color',y='price',data=df)
plt.title('Price vs Color')
plt.show()

# %%
sns.barplot(x = 'clarity', y = 'price', data = df)
# Out:
# <Axes: xlabel='clarity', ylabel='price'>

# %%
#changing categorical variables to numerical variables

# %%
df['cut'] = df['cut'].map({'Ideal':5,'Premium':4,'Very Good':3,'Good':2,'Fair':1})
df['color'] = df['color'].map({'D':7,'E':6,'F':5,'G':4,'H':3,'I':2,'J':1})
df['clarity'] = df['clarity'].map({'IF':8,'VVS1':7,'VVS2':6,'VS1':5,'VS2':4,'SI1':3,'SI2':2,'I1':1})

# %%
df.corr()
# Out:
#             carat       cut     color   clarity     depth     table     price  \
# carat    1.000000 -0.135135 -0.291530 -0.352435  0.027734  0.183639  0.921804
# cut     -0.135135  1.000000  0.019548  0.189024 -0.223898 -0.432154 -0.053537
# color   -0.291530  0.019548  1.000000 -0.026056 -0.047426 -0.027513 -0.172629
# clarity -0.352435  0.189024 -0.026056  1.000000 -0.067329 -0.159967 -0.146941
# depth    0.027734 -0.223898 -0.047426 -0.067329  1.000000 -0.293012 -0.012731
# table    0.183639 -0.432154 -0.027513 -0.159967 -0.293012  1.000000  0.129848
# price    0.921804 -0.053537 -0.172629 -0.146941 -0.012731  0.129848  1.000000
# x        0.975037 -0.125738 -0.270529 -0.371355 -0.025563  0.197198  0.884919
# y        0.950035 -0.121335 -0.263395 -0.357226 -0.029809  0.185248  0.864393
# z        0.952700 -0.149830 -0.268388 -0.366218  0.094337  0.153161  0.860963
#
#                 x         y         z
# carat    0.975037  0.950035  0.952700
# cut     -0.125738 -0.121335 -0.149830
# color   -0.270529 -0.263395 -0.268388
# clarity -0.371355 -0.357226 -0.366218
# depth   -0.025563 -0.029809  0.094337
# table    0.197198  0.185248  0.153161
# price    0.884919  0.864393  0.860963
# x        1.000000  0.972977  0.970122
# y        0.972977  1.000000  0.950030
# z        0.970122  0.950030  1.000000

# %%
#plotting the correlation heatmap

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
##plotting the correlation heatmap

# %%
sns.lineplot(x='carat',y='price',data=df)
plt.title('Carat vs Price')
plt.show()

# %%
fig, ax = plt.subplots(2,3,figsize=(15,5))
sns.scatterplot(x='x',y='carat',data=df, ax=ax[0,0])
sns.scatterplot(x='y',y='carat',data=df, ax=ax[0,1])
sns.scatterplot(x='z',y='carat',data=df, ax=ax[0,2])
sns.scatterplot(x='x',y='price',data=df, ax=ax[1,0])
sns.scatterplot(x='y',y='price',data=df, ax=ax[1,1])
sns.scatterplot(x='z',y='price',data=df, ax=ax[1,2])
# Out:
# <Axes: xlabel='z', ylabel='price'>

# %%
#Train Test Split

# %%
from sklearn.model_selection import train_test_split
x_test,x_train,y_test,y_train = train_test_split(df.drop('price',axis=1),df['price'],test_size=0.2,random_state=42)

# %%
#Model Building
Decision Tree Regressor

# %%
#training the model
dt.fit(x_train,y_train)
#train accuracy
dt.score(x_train,y_train)
# Out:
# 0.9999995617234543

# %%
#training the model
rf.fit(x_train,y_train)
#train accuracy
rf.score(x_train,y_train)
# Out:
# 0.9970489911076822

# %%
#Model Evaluation

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
ax = sns.distplot(y_test,hist=False,color='b',label='Actual Value')
sns.distplot(dt_pred,hist=False,color='y',label='Fitted Values',ax=ax)
plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price')
plt.ylabel('Proportion of Diamonds')
plt.show()
# Out:
# C:\Users\meena\AppData\Local\Temp\ipykernel_18128\1786319433.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(y_test,hist=False,color='b',label='Actual Value')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[83], line 2
#       1 ax = sns.distplot(y_test,hist=False,color='b',label='Actual Value')
# ----> 2 sns.distplot(dt_pred,hist=False,color='y',label='Fitted Values',ax=ax)
#       3 plt.title('Actual vs Fitted Values for Price')
#       4 plt.xlabel('Price')
#
# NameError: name 'dt_pred' is not defined

# %%
#Random Forest Regressor

# %%
ax = sns.distplot(y_test,hist=False,color='y',label='Actual Value')
sns.distplot(rf_pred,hist=False,color='b',label='Fitted Values',ax=ax)
plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price')
plt.ylabel('Proportion of Diamonds')
plt.show()
# Out:
# C:\Users\meena\AppData\Local\Temp\ipykernel_18128\2870579607.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(y_test,hist=False,color='y',label='Actual Value')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[86], line 2
#       1 ax = sns.distplot(y_test,hist=False,color='y',label='Actual Value')
# ----> 2 sns.distplot(rf_pred,hist=False,color='b',label='Fitted Values',ax=ax)
#       3 plt.title('Actual vs Fitted Values for Price')
#       4 plt.xlabel('Price')
#
# NameError: name 'rf_pred' is not defined
